# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/placement.csv')

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
plt.figure(figsize=(3,4))
sns.boxplot(df['placement_exam_marks'])
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.distplot(df['placement_exam_marks'])
plt.show()
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_9396\947313667.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])

# %%
Q1 = df['placement_exam_marks'].quantile(0.25)
Q3 = df['placement_exam_marks'].quantile(0.75)
iqr = Q3 - Q1

# %%
upper_limit = Q3 + 1.5 * iqr
lower_limit = Q1 - 1.5 * iqr

# %%
#Finding
df[(df['placement_exam_marks'] > upper_limit) | (df['placement_exam_marks'] < lower_limit)]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                  94.0       1
# 40   6.60                  86.0       1
# 61   7.51                  86.0       0
# 134  6.33                  93.0       0
# 162  7.80                  90.0       0
# 283  7.09                  87.0       0
# 290  8.38                  87.0       0
# 311  6.97                  87.0       1
# 324  6.64                  90.0       0
# 630  6.56                  96.0       1
# 685  6.05                  87.0       1
# 730  6.14                  90.0       1
# 771  7.31                  86.0       1
# 846  6.99                  97.0       0
# 917  5.95                 100.0       0

# %%
# removing
new_df = df[(df['placement_exam_marks'] < upper_limit) & (df['placement_exam_marks'] > lower_limit)]
#new_df
plt.figure(figsize=(3,4))
sns.boxplot(new_df['placement_exam_marks'])
plt.show()

# %%
Q1 = new_df['placement_exam_marks'].quantile(0.25)
Q3 = new_df['placement_exam_marks'].quantile(0.75)
iqr=Q3-Q1

# %%
upper_limit = Q3 + 1.5 * iqr
lower_limit = Q1 - 1.5 * iqr

# %%
new_df[(df['placement_exam_marks'] > upper_limit) | (df['placement_exam_marks'] < lower_limit)]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_9396\1471197262.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_df[(df['placement_exam_marks'] > upper_limit) | (df['placement_exam_marks'] < lower_limit)]
#      cgpa  placement_exam_marks  placed
# 403  6.71                  83.0       0

# %%
new_df1 = df[(df['placement_exam_marks'] < upper_limit) & (df['placement_exam_marks'] > lower_limit)]
new_df1
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [984 rows x 3 columns]

# %%
plt.figure(figsize=(3,4))
sns.boxplot(new_df1['placement_exam_marks'])
plt.show()

# %%
#replacing
df['placement_exam_marks'] = np.where(
    df['placement_exam_marks'] > upper_limit,
    upper_limit,
    np.where(
        df['placement_exam_marks'] < lower_limit,
        lower_limit,
        df['placement_exam_marks']
    )
)
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
df['placement_exam_marks'][996]
# Out:
# 65.0

# %%
plt.figure(figsize=(3,4))
sns.boxplot(df['placement_exam_marks'])
plt.show()
