# %%
import pandas as pd
df1 = pd.read_csv('dataset/student.csv')
df1
# Out:
#         Reg_no                             Name
# 0   393CS22706             SUSHMA SURESH RATHOD
# 1   393CS22707             VIJAYAKUMAR  CHAPPAR
# 2   393CS22704                  KRISHNA  GEJAGE
# 3   393CS22705      SAHANA SHARANAGOUDA SURANUR
# 4   393CS22701              ABHISHEK  HATTARAKI
# 5   393CS21039               SUJATA RAJU JADHAV
# 6   393CS21013            HONMANE VIKAS BABUSHA
# 7   393CS21017    MAHAJANKATTI KAUSTUBH GURURAJ
# 8   393CS21024      PRANAV GURUBASSAYA HIREMATH
# 9   393CS21006                        BASAMMA
# 10  393CS21041        VAISHNAVI RAMANNA MALAGAR
# 11  393CS21007   BIRADAR VIJAYALAXMI RUDRAGOUDA
# 12  393CS21008      CHETAN MANIKPRABHU ANKALAGI
# 13  393CS21036      SOUMYA APPASAHEB ITTANGIHAL
# 14  393CS21034             SHAHEEN SALEEM MULLA
# 15  393CS21020                  NIKITA  CHAVHAN
# 16  393CS21022                 PRADEEP R KONNUR
# 17  393CS21028         SACHIN SHRISHAIL BIRADAR
# 18  393CS21003        AISHWARYA HANAMANT BELLAD
# ...

# %%
import pandas as pd
df2 = pd.read_csv('dataset/marks.csv')
df2
# Out:
#         Reg_no  OSA  CN
# 0   393CS22706   44  45
# 1   393CS22707   97  47
# 2   393CS22704   97  47
# 3   393CS22705   97  52
# 4   393CS22701   75  21
# 5   393CS21039   11  23
# 6   393CS21013   87  92
# 7   393CS21017   45  78
# 8   393CS21024   97  17
# 9   393CS21006   97  47
# 10  393CS21041   23  45
# 11  393CS21007   87  65
# 12  393CS21008   61  39
# 13  393CS21036   33  39
# 14  393CS21034   53  44
# 15  393CS21020   56  62
# 16  393CS21022   22  65
# 17  393CS21028   45  20
# 18  393CS21003   25  15
# 19  393CS21026   90  74
# 20  393CS21040   31  94
# 21  393CS21023   93   3
# 22  393CS21015   41  89
# 23  393CS21011   32  57
# 24  393CS21005   90  91
# 25  393CS21010   76  72
# 26  393CS21001   17  30
# 27  393CS21002   58  49
# 28  393CS21037    4  24
# 29  393CS21029   86  70
# 30  393CS21042   24  87
# 31  393CS21019   20  11
# 32  393CS21004   37  58
# 33  393CS21038   31  94
# 34  393CS21016    7  31
# 35  393CS21012   95  77
# 36  393CS21030   61  84
# ...

# %%
df = pd.merge(df1,df2,on='Reg_no')
df
# Out:
#         Reg_no                             Name  OSA  CN
# 0   393CS22706             SUSHMA SURESH RATHOD   44  45
# 1   393CS22707             VIJAYAKUMAR  CHAPPAR   97  47
# 2   393CS22704                  KRISHNA  GEJAGE   97  47
# 3   393CS22705      SAHANA SHARANAGOUDA SURANUR   97  52
# 4   393CS22701              ABHISHEK  HATTARAKI   75  21
# 5   393CS21039               SUJATA RAJU JADHAV   11  23
# 6   393CS21013            HONMANE VIKAS BABUSHA   87  92
# 7   393CS21017    MAHAJANKATTI KAUSTUBH GURURAJ   45  78
# 8   393CS21024      PRANAV GURUBASSAYA HIREMATH   97  17
# 9   393CS21006                        BASAMMA     97  47
# 10  393CS21041        VAISHNAVI RAMANNA MALAGAR   23  45
# 11  393CS21007   BIRADAR VIJAYALAXMI RUDRAGOUDA   87  65
# 12  393CS21008      CHETAN MANIKPRABHU ANKALAGI   61  39
# 13  393CS21036      SOUMYA APPASAHEB ITTANGIHAL   33  39
# 14  393CS21034             SHAHEEN SALEEM MULLA   53  44
# ...

# %%
df['Total_marks']=df['OSA']+df['CN']
df
# Out:
#         Reg_no                             Name  OSA  CN  Totle_marks  \
# 0   393CS22706             SUSHMA SURESH RATHOD   44  45           89
# 1   393CS22707             VIJAYAKUMAR  CHAPPAR   97  47          144
# 2   393CS22704                  KRISHNA  GEJAGE   97  47          144
# 3   393CS22705      SAHANA SHARANAGOUDA SURANUR   97  52          149
# 4   393CS22701              ABHISHEK  HATTARAKI   75  21           96
# 5   393CS21039               SUJATA RAJU JADHAV   11  23           34
# 6   393CS21013            HONMANE VIKAS BABUSHA   87  92          179
# 7   393CS21017    MAHAJANKATTI KAUSTUBH GURURAJ   45  78          123
# 8   393CS21024      PRANAV GURUBASSAYA HIREMATH   97  17          114
# 9   393CS21006                        BASAMMA     97  47          144
# 10  393CS21041        VAISHNAVI RAMANNA MALAGAR   23  45           68
# 11  393CS21007   BIRADAR VIJAYALAXMI RUDRAGOUDA   87  65          152
# ...

# %%
df['percentage']=df['Total_marks']/200*100
df
# Out:
#         Reg_no                             Name  OSA  CN  Totle_marks  \
# 0   393CS22706             SUSHMA SURESH RATHOD   44  45           89
# 1   393CS22707             VIJAYAKUMAR  CHAPPAR   97  47          144
# 2   393CS22704                  KRISHNA  GEJAGE   97  47          144
# 3   393CS22705      SAHANA SHARANAGOUDA SURANUR   97  52          149
# 4   393CS22701              ABHISHEK  HATTARAKI   75  21           96
# 5   393CS21039               SUJATA RAJU JADHAV   11  23           34
# 6   393CS21013            HONMANE VIKAS BABUSHA   87  92          179
# 7   393CS21017    MAHAJANKATTI KAUSTUBH GURURAJ   45  78          123
# 8   393CS21024      PRANAV GURUBASSAYA HIREMATH   97  17          114
# 9   393CS21006                        BASAMMA     97  47          144
# 10  393CS21041        VAISHNAVI RAMANNA MALAGAR   23  45           68
# 11  393CS21007   BIRADAR VIJAYALAXMI RUDRAGOUDA   87  65          152
# ...

# %%
df.to_csv('C:/Users/bldea/sumeeth/dataset/new_stu.csv', index=False)

# %%
new_stu1 = pd.read_csv('dataset/new_stu1.csv')
new_stu1
# Out:
#        Reg_no    Name  OSA  CN  Total_marks  Percentage
# 0  393CS21001   Rahul   55  88          143        71.5
# 1  393CS21002  Ramesh   76  45          121        60.5
# 2  393CS21003   Pooja   56  67          123        61.5
# 3  393CS21004  shweta   80  56          136        68.0

# %%
new_student = pd.read_csv('dataset/new_stu.csv')
new_student
# Out:
#                                      Reg_no  Name  OSA   CN  Total_marks  \
# 393CS22706             SUSHMA SURESH RATHOD    44   45   89           89
# 393CS22707             VIJAYAKUMAR  CHAPPAR    97   47  144          144
# 393CS22704                  KRISHNA  GEJAGE    97   47  144          144
# 393CS22705      SAHANA SHARANAGOUDA SURANUR    97   52  149          149
# 393CS22701              ABHISHEK  HATTARAKI    75   21   96           96
# 393CS21039               SUJATA RAJU JADHAV    11   23   34           34
# 393CS21013            HONMANE VIKAS BABUSHA    87   92  179          179
# 393CS21017    MAHAJANKATTI KAUSTUBH GURURAJ    45   78  123          123
# 393CS21024      PRANAV GURUBASSAYA HIREMATH    97   17  114          114
# 393CS21006                        BASAMMA      97   47  144          144
# 393CS21041        VAISHNAVI RAMANNA MALAGAR    23   45   68           68
# 393CS21007   BIRADAR VIJAYALAXMI RUDRAGOUDA    87   65  152          152
# ...

# %%
df=new_student.append(new_stu1,ignore_index=True)
df
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10200\2151337712.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=new_student.append(new_stu1,ignore_index=True)
#                              Reg_no    Name  OSA   CN  Total_marks  Percentage
# 0              SUSHMA SURESH RATHOD      44   45   89           89        44.5
# 1              VIJAYAKUMAR  CHAPPAR      97   47  144          144        72.0
# 2                   KRISHNA  GEJAGE      97   47  144          144        72.0
# 3       SAHANA SHARANAGOUDA SURANUR      97   52  149          149        74.5
# 4               ABHISHEK  HATTARAKI      75   21   96           96        48.0
# 5                SUJATA RAJU JADHAV      11   23   34           34        17.0
# 6             HONMANE VIKAS BABUSHA      87   92  179          179        89.5
# 7     MAHAJANKATTI KAUSTUBH GURURAJ      45   78  123          123        61.5
# ...
